# %%
Consider the data sets “Sine_30”. 
The points were generated by adding uniformly distributed noise to data coming from a sinusoidal curve. 
Using the Least Squares approach, fit polynomials of degree M=1,2,….,9. Show the plots of the polynomial fits.
